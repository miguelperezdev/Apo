# %% [markdown]
# <a href="https://colab.research.google.com/github/miguelperezdev/Apo/blob/main/Copia_de_Matem%C3%A1ticas_Aplicadas_III_Entrega9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src=http://www.acofi.edu.co/eiei2016/wp-content/uploads/2016/09/Logo-Universidad-ICESI.jpg width="300" height="200" align="center">
#
# #**<big><big>Matemáticas Aplicadas III</big></big><br><small>Depto. Ciencias Fisicas y Exactas / FIDCA</small><br><small>_*Entrega 10*_ (Formas cuadráticas - Descomposición en valores singulares
# ---
#
# A continuación se le pide responder por grupo las siguientes preguntas, utilizando una copia del presente cuaderno para consignar todas sus respuestas con el formato requerido.
#
# La entrega está inicialmente para el día **viernes 7 de noviembre**
#
# **<u>Preguntas</u>**
#
# A continuación encuentra separadas por celda cada pregunta, así usted solo debe continuar escribiendo en la celda para dar cada respuesta. No olvide que todas sus respuestas deben ir acompañadas de al menos un argumento geométrico o numérico y uno algebráico o en lenguaje natural.
#
#
# **Nivel 3: Colaboración con IAG**
#
# Pueden apoyarse en IAG para redactar, sintetizar o clarificar entregables, siempre y cuando
# modifique activamente el contenido generado y lleve un registro de los prompts utilizados.
# Ejemplo: Uso de IAG para estructurar un Cuaderno Colab que involucre simulación de optimización en
# varias variables, explicando cómo se utilizó la herramienta y qué aportó al proceso

# %% [markdown]
# #1. (8 ptos) **Vectores propios**
#
# (a) La matriz $A=\begin{bmatrix}
# 1&10^{-15}\\
# 0&1+10^{-15}
# \end{bmatrix}$ es casi simétrica. Encuentre los vectores propios de $A$ y determine el ángulo entre ellos.
#
# (b) Determine en cada caso si la matriz simétrica $A^TA$ es definida positiva:
#
# $$(i)\;A=\begin{bmatrix}
# 1&2\\
# 0&3
# \end{bmatrix}\quad ii)\;A=\begin{bmatrix}
# 1&1\\
# 1&2\\
# 2&1
# \end{bmatrix}\quad iii)\;A=\begin{bmatrix}
# 1&1&2\\
# 1&2&1
# \end{bmatrix}$$

# %% [markdown]
# ## **Solución Punto 1: Vectores Propios y Matrices Simétricas**
#
# ---
#
# ### **Parte (a)**
#
# La matriz que se analiza es la siguiente:
#
# $$
# A = \begin{bmatrix}
# 1 & 10^{-15} \\
# 0 & 1 + 10^{-15}
# \end{bmatrix}
# $$
# $$$$
# Para encontrar los valores propios se plantea la ecuación característica $\det(A - \lambda I) = 0$. Al calcular el determinante se obtiene:
# $$
# \det \begin{bmatrix}
# 1 - \lambda & 10^{-15} \\
# 0 & 1 + 10^{-15} - \lambda
# \end{bmatrix} = (1 - \lambda)(1 + 10^{-15} - \lambda) = 0
# $$
# $$$$
# De esta ecuación se deduce que los valores propios son:
# $$
# \lambda_1 = 1, \quad \lambda_2 = 1 + 10^{-15}
# $$
# $$$$
# Para hallar los vectores propios se sustituyen estos valores en la ecuación $(A - \lambda I)\mathbf{v} = 0$.
# En el caso de $\lambda_1 = 1$, al realizar la sustitución se obtiene:
# $$
# (A - I)\mathbf{v}_1 = 0 \implies \begin{bmatrix}
# 0 & 10^{-15} \\
# 0 & 10^{-15}
# \end{bmatrix}
# \begin{bmatrix}
# x \\ y
# \end{bmatrix} = \begin{bmatrix}
# 0 \\ 0
# \end{bmatrix}
# $$
# $$$$
# De esta forma se concluye que $y = 0$, y por lo tanto el vector propio asociado es:
# $$
# \mathbf{v}_1 = \begin{bmatrix} 1 \\ 0 \end{bmatrix}
# $$
# $$$$
# Para el segundo valor propio, $\lambda_2 = 1 + 10^{-15}$, se realiza el mismo procedimiento:
# $$
# (A - \lambda_2 I)\mathbf{v}_2 = 0 \implies \begin{bmatrix}
# -10^{-15} & 10^{-15} \\
# 0 & 0
# \end{bmatrix}
# \begin{bmatrix}
# x \\ y
# \end{bmatrix} = \begin{bmatrix}
# 0 \\ 0
# \end{bmatrix}
# $$
# $$$$
# Al resolver se obtiene la relación $x = y$, y por tanto el vector propio es:
# $$
# \mathbf{v}_2 = \begin{bmatrix} 1 \\ 1 \end{bmatrix}
# $$
# $$$$
# Con los vectores propios calculados, se determina el ángulo entre ellos.
# El ángulo $\theta$ se obtiene mediante la expresión:
# $$
# \cos \theta = \frac{\mathbf{v}_1 \cdot \mathbf{v}_2}{\|\mathbf{v}_1\| \|\mathbf{v}_2\|}
# $$
# $$$$
# Al sustituir los valores, se tiene:
# $$
# \mathbf{v}_1 \cdot \mathbf{v}_2 = 1 \cdot 1 + 0 \cdot 1 = 1
# $$
# $$$$
# Y las normas de los vectores son:
# $$
# \|\mathbf{v}_1\| = 1, \quad \|\mathbf{v}_2\| = \sqrt{1^2 + 1^2} = \sqrt{2}
# $$
# $$$$
# Por lo tanto:
# $$
# \cos \theta = \frac{1}{\sqrt{2}} \implies \theta = 45^\circ
# $$
# $$$$
# En consecuencia, los vectores propios de la matriz son $\mathbf{v}_1 = \begin{bmatrix} 1 \\ 0 \end{bmatrix}$ y $\mathbf{v}_2 = \begin{bmatrix} 1 \\ 1 \end{bmatrix}$, con un ángulo entre ellos de $45^\circ$.
# Este resultado muestra que la matriz A es casi idéntica a la identidad, por lo que sus vectores propios también son muy similares a los de la matriz identidad.
# La pequeña perturbación $10^{-15}$ altera ligeramente la estructura de la matriz, provocando que los vectores propios dejen de ser ortogonales.
# El ángulo calculado confirma este comportamiento y se puede comprobar numéricamente usando $cos^{-1}(1/\sqrt{2})$.
#
# ---
#
# ### **Parte (b)**
#
# Para analizar si $A^TA$ es definida positiva, se aplican distintos casos.
# En el primer caso, la matriz es:
# $$
# A = \begin{bmatrix} 1 & 2 \\ 0 & 3 \end{bmatrix}
# $$
# $$$$
# El producto $A^TA$ se obtiene como:
# $$
# A^TA = \begin{bmatrix}
# 1 & 0 \\
# 2 & 3
# \end{bmatrix}
# \begin{bmatrix}
# 1 & 2 \\
# 0 & 3
# \end{bmatrix} = \begin{bmatrix}
# 1 & 2 \\
# 2 & 13
# \end{bmatrix}
# $$
# $$$$
# Para determinar si es definida positiva se aplica el criterio de Sylvester, que evalúa los determinantes principales.
# El primero es $\det(1) = 1 > 0$, y el segundo es $\det(A^TA) = 13 - 4 = 9 > 0$.
# Como ambos son positivos, se concluye que la matriz es definida positiva.
# $$$$
# En el segundo caso, se tiene:
# $$
# A = \begin{bmatrix} 1 & 1 \\ 1 & 2 \\ 2 & 1 \end{bmatrix}
# $$
# $$$$
# El producto $A^TA$ resulta:
# $$
# A^TA = \begin{bmatrix}
# 1 & 1 & 2 \\
# 1 & 2 & 1
# \end{bmatrix}
# \begin{bmatrix}
# 1 & 1 \\
# 1 & 2 \\
# 2 & 1
# \end{bmatrix} = \begin{bmatrix}
# 6 & 5 \\
# 5 & 6
# \end{bmatrix}
# $$
# $$$$
# De nuevo, aplicando el criterio de Sylvester, el primer determinante es $\det(6) = 6 > 0$, y el segundo es $\det(A^TA) = 36 - 25 = 11 > 0$.
# Ambos son positivos, por lo que también es definida positiva.
# $$$$
# Finalmente, el tercer caso considera:
# $$
# A = \begin{bmatrix} 1 & 1 & 2 \\ 1 & 2 & 1 \end{bmatrix}
# $$
# $$$$
# El producto $A^TA$ se calcula como:
# $$
# A^TA = \begin{bmatrix}
# 1 & 1 \\
# 1 & 2 \\
# 2 & 1
# \end{bmatrix}
# \begin{bmatrix}
# 1 & 1 & 2 \\
# 1 & 2 & 1
# \end{bmatrix} = \begin{bmatrix}
# 2 & 3 & 3 \\
# 3 & 5 & 4 \\
# 3 & 4 & 5
# \end{bmatrix}
# $$
# $$$$
# Evaluando los determinantes principales se obtiene que $\det(2) = 2 > 0$, el siguiente determinante $\det \begin{bmatrix} 2 & 3 \\ 3 & 5 \end{bmatrix} = 10 - 9 = 1 > 0$, y el determinante completo es $\det(A^TA) = 2(25 - 16) - 3(15 - 12) + 3(12 - 15) = 0$.
# Esto indica que la matriz no es definida positiva, sino semidefinida positiva, ya que presenta un valor propio igual a cero.

# %% [markdown]
# #2. (7 ptos) **Máximos y mínimos de una forma cuadrática**
#
# Para la forma cuadrática $\mathbf{x}^TA\mathbf{x}$ vimos un resultado que incluía  las siguientes propiedades:
#
# 1. $\lambda_1\leq\mathbf{x}^TA\mathbf{x}\leq\lambda_n$.
# 2. El máximo de $\mathbf{x}^TA\mathbf{x}$ es $\lambda_n$, y ocurre cuando  $\mathbf{x}$ es un vector propio unitario correspondiente a $\lambda_n$.
#
# Demuestre estas propiedades usando el resultado  $\mathbf{x}^TA\mathbf{x}=\mathbf{y}^T\Lambda\mathbf{y}$ obtenido mediante el cambio de variables $\mathbf{y}=V\mathbf{x}$ donde $V$ es la matriz ortogonal de vectores propios de $A$.

# %% [markdown]
# ## **Solución Punto 2: Máximos y Mínimos de una Forma Cuadrática**
#
# ---
#
# ### **Parte (a)**
#
# Se estudia la forma cuadrática $\mathbf{x}^T A \mathbf{x}$ con el objetivo de demostrar que su valor se encuentra acotado entre los valores propios mínimo y máximo de la matriz $A$.
# Dado que $A$ es una matriz simétrica, se puede expresar mediante una diagonalización ortogonal, lo que significa que existen una matriz ortogonal $V$ y una matriz diagonal $\Lambda$ tales que:
# $$
# A = V \Lambda V^T
# $$
# $$$$
# Al realizar el cambio de variable $\mathbf{y} = V^T \mathbf{x}$, se puede reescribir la forma cuadrática como:
# $$
# \mathbf{x}^T A \mathbf{x} = \mathbf{y}^T \Lambda \mathbf{y} = \sum_{i=1}^{n} \lambda_i y_i^2
# $$
# $$$$
# Dado que $V$ es ortogonal, se conserva la norma, por lo tanto $\|\mathbf{y}\| = \|\mathbf{x}\| = 1$.
# Cada término de la suma está ponderado por un valor propio $\lambda_i$, los cuales cumplen $\lambda_1 \leq \lambda_i \leq \lambda_n$.
# Al considerar que $\sum y_i^2 = 1$, se obtiene la desigualdad:
# $$
# \lambda_1 \sum y_i^2 \leq \sum_{i=1}^{n} \lambda_i y_i^2 \leq \lambda_n \sum y_i^2
# $$
# $$$$
# De aquí se deduce que:
# $$
# \lambda_1 \leq \mathbf{x}^T A \mathbf{x} \leq \lambda_n
# $$
# $$$$
# Esto demuestra que el valor de la forma cuadrática está siempre comprendido entre los valores propios mínimo y máximo de la matriz simétrica $A$.
#
# ---
#
# ### **Parte (b)**
#
# El valor máximo de $\mathbf{x}^T A \mathbf{x}$ se alcanza cuando el vector $\mathbf{x}$ se alinea con el vector propio asociado al valor propio máximo $\lambda_n$, ya que en ese caso todas las demás componentes de $\mathbf{y}$ son cero y solo $y_n = 1$.
# De manera análoga, el valor mínimo $\lambda_1$ se obtiene cuando $\mathbf{x}$ es el vector propio asociado al valor propio mínimo $\lambda_1$.
# $$$$
# Por lo tanto, la forma cuadrática alcanza su valor máximo en el vector propio correspondiente a $\lambda_n$ y su valor mínimo en el asociado a $\lambda_1$.
# Estos resultados confirman que los extremos de la forma cuadrática están determinados por los valores propios de la matriz simétrica y que el intervalo de posibles valores está dado por $[\lambda_1, \lambda_n]$.
# Esta propiedad es esencial en el análisis de formas cuadráticas y en la teoría de optimización, pues permite comprender cómo la orientación del vector $\mathbf{x}$ influye en los valores de $\mathbf{x}^T A \mathbf{x}$.

# %% [markdown]
# #3. (10 ptos) **Teorema de los ejes principales**
#
# Para  la siguiente matriz,  $$A=\begin{bmatrix}
# 1&1&-1&-6&-7\\
# 1&0&3&3&-6\\
# -1&3&12&4&-4\\
# -6&3&4&1&-2\\
# -7&-6&-4&-2&3
# \end{bmatrix}$$
#
# considere la forma cuadrática $q(\mathbf{x}) = \mathbf{x}^TA\mathbf{x}$. Encuentre la dirección de los ejes  principales, de  manera tal que la forma cuadrática $q$ tiene la forma canónica en un nuevo sistema de coordenadas $y_1,..., y_2$. Utilizando todos los vectores propios (unitarios), determine ¿Cuál es el valor máximo  y cual es el  valor mínimo de $q(x)$ sobre la bola unitaria en $\mathbb{R}^5$? Justifique sus respuestas.

# %% [markdown]
# Dada la matriz
#
# $$
# A = \begin{bmatrix}
# 1 & 1 & -1 & -6 & -7 \\
# 1 & 0 & 3 & 3 & -6 \\
# -1 & 3 & 12 & 4 & -4 \\
# -6 & 3 & 4 & 1 & -2 \\
# -7 & -6 & -4 & -2 & 3
# \end{bmatrix}
# $$
#
# se considera la forma cuadrática $q(\mathbf{x}) = \mathbf{x}^T A \mathbf{x}$.
# El objetivo es encontrar las direcciones de los ejes principales de manera que $q$ pueda expresarse en forma canónica dentro de un nuevo sistema de coordenadas $y_1, \dots, y_5$.
# Para esto, se emplean los vectores propios unitarios de $A$, que determinan las direcciones de los ejes principales.
#
# La matriz con los vectores propios normalizados obtenidos mediante el código adjunto es:
#
# $$
# P = \begin{bmatrix}
# 0.05502244 & 0.68132158 & -0.24378075 & -0.67273187 & -0.14413957 \\
# 0.34539846 & 0.17732751 & 0.46993653 & -0.13000125 & 0.78199373 \\
# 0.77510395 & -0.28124467 & -0.5623911 & -0.02932413 & 0.05451279 \\
# 0.29203848 & -0.38286777 & 0.57347582 & -0.47199597 & -0.46526454 \\
# -0.43772118 & -0.52789163 & -0.27307937 & -0.5539778 & 0.38505436
# \end{bmatrix}
# $$
#
# Cada columna de $P$ representa un vector propio normalizado asociado a un valor propio distinto de $A$:
#
# $$
# \lambda_1 = 17.03185611, \quad
# \lambda_2 = 10.4683926, \quad
# \lambda_3 = 3.03860102, \quad
# \lambda_4 = -8.82433502, \quad
# \lambda_5 = -4.71451471.
# $$
#
# Los vectores propios unitarios asociados son:
#
# $$
# v_1 =
# \begin{bmatrix}
# 0.05502244 \\ 0.34539846 \\ 0.77510395 \\ 0.29203848 \\ -0.43772118
# \end{bmatrix}, \quad
# v_2 =
# \begin{bmatrix}
# -0.24378075 \\ 0.46993653 \\ -0.5623911 \\ 0.57347582 \\ -0.27307937
# \end{bmatrix},
# $$
# $$
# v_3 =
# \begin{bmatrix}
# 0.68132158 \\ 0.17732751 \\ -0.28124467 \\ -0.38286777 \\ -0.52789163
# \end{bmatrix}, \quad
# v_4 =
# \begin{bmatrix}
# -0.67273187 \\ -0.13000125 \\ -0.02932413 \\ -0.47199597 \\ -0.5539778
# \end{bmatrix}, \quad
# v_5 =
# \begin{bmatrix}
# -0.14413957 \\ 0.78199373 \\ 0.05451279 \\ -0.46526454 \\ 0.38505436
# \end{bmatrix}
# $$
#
# Como la matriz $A$ es simétrica y tiene valores propios distintos, sus vectores propios son ortogonales entre sí y al estar normalizados forman una base ortonormal en $\mathbb{R}^5$.
# Por lo tanto, estos vectores definen las direcciones principales del sistema.
#
# Ahora bien, para la determinación del valor máximo y mínimo de $q(\mathbf{x})$ sobre la bola unitaria, sabemos por el Teorema de los Ejes Principales que si $A$ es simétrica de orden $n \times n$ con valores propios $\lambda_1 \leq \lambda_2 \leq \dots \leq \lambda_n$, entonces para cualquier vector unitario $\mathbf{x} \in \mathbb{R}^n$ se cumple que:
#
# 1. $\lambda_1 \leq \mathbf{x}^T A \mathbf{x} \leq \lambda_n$.¿
# 2. El mínimo de $\mathbf{x}^T A \mathbf{x}$ es $\lambda_1$ y ocurre cuando $\mathbf{x}$ es el vector propio unitario correspondiente a $\lambda_1$
# 3. El máximo de $\mathbf{x}^T A \mathbf{x}$ es $\lambda_n$ y ocurre cuando $\mathbf{x}$ es el vector propio unitario correspondiente a $\lambda_n$
#
# Teniendo esto en cuenta, sobre la bola unitaria en $\mathbb{R}^5$:
#
# $$
# q_{\min} = \lambda_{\min} = -8.82433502, \quad
# q_{\max} = \lambda_{\max} = 17.03185611.
# $$
#
# Entonces se dice que las direcciones de los ejes principales están dadas por los vectores propios unitarios de $A$, y los valores máximo y mínimo de la forma cuadrática sobre la bola unitaria corresponden a los valores propios mayor y menor respectivamente

# %%
import numpy as np
from numpy.linalg import eig
import random

E, V = eig([[1,1,-1,-6,-7],[1,0,3,3,-6],[-1,3,12,4,-4],[-6,3,4,1,-2],[-7,-6,-4,-2,3]])

print('Eigenvalues : ', E,'\n')
print('Eigenvectors : \n', V,'\n')
# Out:
# Eigenvalues :  [17.03185611 10.4683926   3.03860102 -8.82433502 -4.71451471]
#
# Eigenvectors :
#  [[ 0.05502244  0.68132158 -0.24378075 -0.67273187 -0.14413957]
#  [ 0.34539846  0.17732751  0.46993653 -0.13000125  0.78199373]
#  [ 0.77510395 -0.28124467 -0.5623911  -0.02932413  0.05451279]
#  [ 0.29203848 -0.38286777  0.57347582 -0.47199597 -0.46526454]
#  [-0.43772118 -0.52789163 -0.27307937 -0.5539778   0.38505436]]

# %% [markdown]
# #4. (10 ptos) **Descomposición en valores singulares**
#
# Considere la matriz $A=\begin{bmatrix}
# 3&0\\
# 4&5
# \end{bmatrix}$.
#
# Paso#1:
# Encuentre los valores propios de $A^TA$. Estos valores propios son los denominados *valores singulares* $\sigma_i$ al cuadrado de la matriz $A$  y sus vectores propios unitarios asociados son los respectivos vectores singulares $\mathbf{v}_i$ por izquierda.
#
# Paso#2:
# Los vectores singulares por derecha $\mathbf{u}_i$ se calculan mediante $$\mathbf{u}_i=\frac{A\mathbf{v}_i}{\sigma_i}.$$ ¿Que relación existe entre estos vectores $\mathbf{u}_i$  y los vectores propios de $AA^T$?
#
# Paso#2a:
# Normalice los vectores  $\mathbf{u}_i$
#
# Paso #3:
# Construya las matrices $$U=[\mathbf{u}_1\;\mathbf{u}_2],\quad \Sigma = diag(\sigma_1,\sigma_2)\quad V= [\mathbf{v}_1\; \mathbf{v}_2]$$
#
# La anterior construcción debe permitir comprobar que $$A=U\Sigma V^T$$
# y se denomina la *descomposición en valores singulares*, (SVD) por sus siglas en inglés, de $A$. Verifique la igualdad.

# %% [markdown]
# #5. (15 ptos) **Solución de sistemas lineales mal puestos (ill-posed)**
#
# > *The expression `ill-conditioned' is sometimes used
# merely as a term of abuse . . . It is characteristic of
# ill-conditioned sets of equations that small percentage
# errors in the coefficients given may lead to large
# percentage errors in the solution.
# Alan Turing, 1934 (Higham 1996, p.131)*
#
#
#
# Recordemos que en el cuaderno 5 estudiamos un ejemplo de sistemas denominados mal condicionados, puesto que pequeños cambios en la matriz $A$ o el vector $\mathbf{b}$ producen grandes cambios en la solución $\mathbf{x}$. Para ilustrar ese comportamiento utilizamos la matrix de Hilbert:
#
# $$H=[h_{ij}]=\frac{1}{1+i+j}$$ y $\mathbf{x}=ones(n)$. El vector $\mathbf{b}$ se construía  multiplicando $H$ por $\mathbf{x}$. Usted va a usar ahora el siguiente procedimiento para intentar reducir el impacto de la mala condición de la matriz $H$, utilizando la descomposición SVD de $H$, para hallar la solución correcta. Es importante anotar que para encontrar el *número de condición* de una matriz se utiliza la razón $\frac{\sigma_1}{\sigma_{\min(m,n)}}$. De esta forma usted puede previamente saber si su sistema lineal está mal condicionado o no.
#
# **Solución del sistema $H\mathbf{x}=\mathbf{b}$ via SVD**
#
# Paso#1.
# Obtenga la factorización SVD de $H$. ($H=U\Sigma V^T$) (U, S, V = linalg.svd(A, full_matrices=False))
#
# Paso#2.
# Resuelva $U\mathbf{z}=\mathbf{b}$ ($\mathbf{z}=U^T\mathbf{b}$)
#
# Paso#3.
# Identifique los valores singulares no nulos $\sigma_1\geq\sigma_2\geq\cdots\sigma_r>0$ y los valores singulares nulos $\sigma_{r+1}=\cdots=\sigma_{\min(m,n)}=0$. Resuelva $\Sigma \mathbf{y}=\mathbf{z}$:
#
#
# *   Si $z_i\not=0$ para algún $i=r+1,...,m$ no hay solución (debe buscarse entonces la factorización SVD utilizando las ecuaciones normales (mínimos cuadrados))
# *   Si $z_i=0$ entonces  $i=r+1,...,m$ determine la $i-$ésima componente de $\mathbf{y}$ como $y_i=\frac{z_i}{\sigma_i}$ para $i=1,..,r$.
#
# Paso#4
# Resuelva $V^T\mathbf{x}=\mathbf{y}$, es decir, halle $\mathbf{x}=V\mathbf{y}$.
#
# El anterior procedimiento se puede resumir en el siguiente cálculo:
#
# $$\mathbf{x}=\sum_{i=0}^r\frac{\mathbf{u}_i^T\mathbf{b}}{\sigma_i}\mathbf{v}_i,$$ donde los vectores $\mathbf{u}_i$ y $\mathbf{v}_i$ son los vectores columna de las matries $U$ y $V$ respectivamente, y $r$ es el rango de la matriz $H$, correspondiente al número de valores singulares no nulos.
#
# i) Usted debe implementar el anterior algoritmo y usarlo para resolver el sistema $$H\mathbf{x}=\mathbf{b}$$ para $n=5,10, 15$ y $20$ primero considerando todos los valores singulares (su solución se irá degradando en la medida que $n$ crezca) y luego utilizando tantos valores singulares como indique el rango $r$ (su solución no se degradará tanto).
#
# ii) Resuelva los sistemas utilizando linalg.solve  y el algoritmo anterior. Debe hacer una tabla para cada algoritmo y cada $n$ con los siguientes valores:
#
# $$||\mathbf{b}-H\mathbf{x}||,\quad \frac{||\mathbf{x}_{true}-\mathbf{x}||}{||\mathbf{x}_{true}||}$$
#
# donde $\mathbf{x}_{true}=ones(n)$. Estos resultados le permitirán escribir conjeturas sobre la precisión de su solución y si en cada caso se está resolviendo el problema original.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

np.set_printoptions(precision=6, suppress=True)

def hilbert_matrix(n):
    i = np.arange(n).reshape(-1,1)
    j = np.arange(n).reshape(1,-1)
    return 1.0 / (1 + i + j)

def svd_solve_full(H, b):
    U, s, Vt = np.linalg.svd(H, full_matrices=False)
    x = np.zeros(H.shape[1])
    for i in range(len(s)):
        ui = U[:, i]
        vi = Vt.T[:, i]
        x += (ui.T @ b) / s[i] * vi
    return x, (U, s, Vt)

def svd_solve_truncated(H, b, tol=None):
    U, s, Vt = np.linalg.svd(H, full_matrices=False)
    eps = np.finfo(float).eps
    if tol is None:
        tol = max(H.shape) * eps * s[0]   # regla  para tolerancia
    r = np.sum(s > tol)
    x = np.zeros(H.shape[1])
    for i in range(r):
        ui = U[:, i]
        vi = Vt.T[:, i]
        x += (ui.T @ b) / s[i] * vi
    return x, r, (U, s, Vt, tol)

def run_experiment(ns=[5,10,15,20]):
    rows = []
    tables = {}
    for n in ns:
        H = hilbert_matrix(n)
        x_true = np.ones(n)
        b = H @ x_true

        # Direct solve (Gaussian elimination)
        try:
            x_direct = np.linalg.solve(H, b)
        except np.linalg.LinAlgError:
            x_direct = np.full(n, np.nan)

        # SVD full reconstruction
        x_svd_full, svd_full = svd_solve_full(H, b)

        # SVD truncated (based on tol)
        x_svd_trunc, r, svd_trunc = svd_solve_truncated(H, b)

        # errors
        def rel_err(x):
            return np.linalg.norm(x_true - x) / np.linalg.norm(x_true)
        def res_norm(x):
            return np.linalg.norm(b - H @ x)

        # condition number (using nonzero smallest singular value)
        s = svd_full[1]
        sigma1 = s[0]
        sigman = s[-1] if s[-1] > 0 else np.nan
        cond = sigma1 / sigman if sigman and sigman > 0 else np.inf

        rows.append({'n': n, 'method': 'direct_solve',
                     'residual_norm': res_norm(x_direct),
                     'relative_error': rel_err(x_direct),
                     'cond(H)': cond})
        rows.append({'n': n, 'method': 'svd_full',
                     'residual_norm': res_norm(x_svd_full),
                     'relative_error': rel_err(x_svd_full),
                     'cond(H)': cond})
        rows.append({'n': n, 'method': f'svd_trunc_r={r}',
                     'residual_norm': res_norm(x_svd_trunc),
                     'relative_error': rel_err(x_svd_trunc),
                     'cond(H)': cond})

        tables[n] = {'H': H, 'b': b, 'x_true': x_true,
                     'x_direct': x_direct, 'x_svd_full': x_svd_full,
                     'x_svd_trunc': x_svd_trunc, 'singular_values': s,
                     'r': r, 'tol': svd_trunc[3], 'cond': cond}
    df = pd.DataFrame(rows)
    return df, tables

# Ejecutar experimento
df_results, tables = run_experiment([5,10,15,20])

# Mostrar resultados como DataFrame (Colab lo renderiza bonito)
df_results_display = df_results.copy()
# formatear números para visualización
df_results_display['residual_norm'] = df_results_display['residual_norm'].map(lambda v: f"{v:.3e}")
df_results_display['relative_error'] = df_results_display['relative_error'].map(lambda v: f"{v:.3e}")
df_results_display['cond(H)'] = df_results_display['cond(H)'].map(lambda v: f"{v:.3e}" if np.isfinite(v) else "inf")
display(df_results_display)

# Graficar decay de valores singulares para cada n
for n, info in tables.items():
    s = info['singular_values']
    plt.figure(figsize=(6,3.5))
    plt.semilogy(np.arange(1, len(s)+1), s, marker='o')
    plt.title(f"Singular values decay (n={n}), rank r={info['r']}, tol={info['tol']:.3e}")
    plt.xlabel("Índice i")
    plt.ylabel("σ_i (escala log)")
    plt.grid(True, which='both', ls='--', lw=0.5)
    plt.tight_layout()
    plt.show()

# Imprimir resumen en texto (opcional)
for n, info in tables.items():
    print(f"n = {n}: r = {info['r']}, tol = {info['tol']:.3e}, cond(H) ≈ {info['cond']:.3e}")
    print(" primeras singulares:", np.array2string(info['singular_values'][:min(10,len(info['singular_values']))], precision=6))
    print()
# Out:
#      n          method residual_norm relative_error    cond(H)
# 0    5    direct_solve     2.719e-16      1.683e-12  4.766e+05
# 1    5        svd_full     4.192e-15      2.527e-11  4.766e+05
# 2    5   svd_trunc_r=5     4.192e-15      2.527e-11  4.766e+05
# 3   10    direct_solve     5.661e-16      8.670e-05  1.602e+13
# 4   10        svd_full     1.047e-15      1.608e-06  1.602e+13
# 5   10  svd_trunc_r=10     1.047e-15      1.608e-06  1.602e+13
# 6   15    direct_solve     1.211e-15      4.930e+00  3.676e+17
# 7   15        svd_full     1.632e-15      6.090e+00  3.676e+17
# 8   15  svd_trunc_r=12     1.494e-15      6.165e-03  3.676e+17
# 9   20    direct_solve     1.434e-14      7.012e+01  1.148e+18
# 10  20        svd_full     7.687e-15      1.737e+01  1.148e+18
# 11  20  svd_trunc_r=13     5.682e-15      2.143e-03  1.148e+18
# n = 5: r = 5, tol = 1.740e-15, cond(H) ≈ 4.766e+05
#  primeras singulares: [1.567051 0.208534 0.011407 0.000306 0.000003]
#
# ...
